# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
link = 'https://contenido.bce.fin.ec/documentos/Estadisticas/SectorMonFin/TasasInteres/TasasVigentes'

# %%
for ano in range(2007, 2027):
    for x in range(13):
        if x < 10:
            print(link + '0' + str(x) + str(ano) + '.htm')
        else:
            print(link + str(x) + str(ano) + '.htm')
# Out:
# https://contenido.bce.fin.ec/documentos/Estadisticas/SectorMonFin/TasasInteres/TasasVigentes002007.htm
# https://contenido.bce.fin.ec/documentos/Estadisticas/SectorMonFin/TasasInteres/TasasVigentes012007.htm
# https://contenido.bce.fin.ec/documentos/Estadisticas/SectorMonFin/TasasInteres/TasasVigentes022007.htm
# https://contenido.bce.fin.ec/documentos/Estadisticas/SectorMonFin/TasasInteres/TasasVigentes032007.htm
# https://contenido.bce.fin.ec/documentos/Estadisticas/SectorMonFin/TasasInteres/TasasVigentes042007.htm
# https://contenido.bce.fin.ec/documentos/Estadisticas/SectorMonFin/TasasInteres/TasasVigentes052007.htm
# https://contenido.bce.fin.ec/documentos/Estadisticas/SectorMonFin/TasasInteres/TasasVigentes062007.htm
# https://contenido.bce.fin.ec/documentos/Estadisticas/SectorMonFin/TasasInteres/TasasVigentes072007.htm
# https://contenido.bce.fin.ec/documentos/Estadisticas/SectorMonFin/TasasInteres/TasasVigentes082007.htm
# ...

# %%
# URL of the page
url = "https://contenido.bce.fin.ec/documentos/informacioneconomica/MonetarioFinanciero/ix_TasasInteres.html"

# Adding headers to look like a real browser
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36"
}

try:
    # If you still have SSL issues locally, you can add verify=False
    response = requests.get(url, headers=headers, verify=True)
    response.raise_for_status()
    
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Find all links that contain 'TasasVigentes'
    links = soup.find_all('a', href=True)
    
    data = []
    
    for link in links:
        href = link['href']
        if "TasasVigentes" in href:
            # The text of the link is the Month (e.g., "Enero")
            month_name = link.get_text(strip=True)
            
            # The parent row (tr) usually contains the Year in the first cell (td)
            parent_row = link.find_parent('tr')
            year = parent_row.find('td').get_text(strip=True) if parent_row else "Unknown"
            
            # Construct full URL if it's relative
            full_url = href if href.startswith('http') else f"https://contenido.bce.fin.ec/documentos/informacioneconomica/MonetarioFinanciero/{href}"
            
            data.append({
                "Year": year,
                "Month": month_name,
                "URL": full_url
            })

    # Create a DataFrame for easy viewing/saving
    df = pd.DataFrame(data)
    
    # Clean up the Year column (sometimes it picks up empty strings or headers)
    df = df[df['Year'].str.isnumeric()]
    
    print(df.head(20))
    
    # Save to CSV if you want
    # df.to_csv("bce_interest_links.csv", index=False)

except Exception as e:
    print(f"Error: {e}")
